# %% [markdown]
# # pandas

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" : ['gaurav','rohan','skillf','shubh'],
    "marks" : [92,34,24,17],
    "city" : ['rampur','kolkata','bareli','antarctica']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0  gaurav     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24      bareli
# 3   shubh     17  antarctica

# %%
df.to_csv('data.csv')

# %%
df.to_csv('data_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#      name  marks     city
# 0  gaurav     92   rampur
# 1   rohan     34  kolkata

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     24      bareli
# 3   shubh     17  antarctica

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
gaurav = pd.read_csv('gaurav.csv')

# %%
gaurav
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Train No  Speed        city
# 0           0             0               0       123     50      rampur
# 1           1             1               1       234     34     kolkata
# 2           2             2               2      3434     24      bareli
# 3           3             3               3      2323     17  antarctica

# %%
gaurav['Speed'][0] = 50
# Out:
# <ipython-input-12-886ff29410e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gaurav['Speed'][0] = 50

# %%
gaurav['Speed']
# Out:
# I      50
# II     34
# III    24
# IV     17
# Name: Speed, dtype: int64

# %%
gaurav
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Train No  Speed        city
# 0           0             0               0       123     50      rampur
# 1           1             1               1       234     34     kolkata
# 2           2             2               2      3434     24      bareli
# 3           3             3               3      2323     17  antarctica

# %%
gaurav.to_csv('gaurav.csv')

# %%
gaurav.index = ['I','II','III','IV']

# %%
gaurav
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Train No  Speed        city
# I             0             0               0       123     50      rampur
# II            1             1               1       234     34     kolkata
# III           2             2               2      3434     24      bareli
# IV            3             3               3      2323     17  antarctica

# %%
gaurav.Speed
# Out:
# I      50
# II     34
# III    24
# IV     17
# Name: Speed, dtype: int64

# %%
gaurav.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    Train No      Speed
# count    4.000000      4.000000        4.000000     4.00000   4.000000
# mean     1.500000      1.500000        1.500000  1528.50000  31.250000
# std      1.290994      1.290994        1.290994  1624.12243  14.314911
# min      0.000000      0.000000        0.000000   123.00000  17.000000
# 25%      0.750000      0.750000        0.750000   206.25000  22.250000
# 50%      1.500000      1.500000        1.500000  1278.50000  29.000000
# 75%      2.250000      2.250000        2.250000  2600.75000  38.000000
# max      3.000000      3.000000        3.000000  3434.00000  50.000000

# %%
ser = pd.Series(np.random.rand(20))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
type(newdf)
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.124952  0.289187  0.200767  0.073675  0.302593
# 1  0.426648  0.659898  0.844340  0.490818  0.227845
# 2  0.304284  0.747584  0.713289  0.185778  0.269347
# 3  0.062237  0.890258  0.687348  0.455395  0.408769
# 4  0.732197  0.700883  0.906334  0.944025  0.976182

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [5 rows x 334 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0       0.3  0.289187  0.200767  0.073675  0.302593
# 1  0.426648  0.659898  0.844340  0.490818  0.227845
# 2  0.304284  0.747584  0.713289  0.185778  0.269347
# 3  0.062237  0.890258  0.687348  0.455395  0.408769
# 4  0.732197  0.700883  0.906334  0.944025  0.976182

# %%
newdf.sort_index(axis=1, ascending=False).head()
# Out:
#           4         3         2         1         0
# 0  0.302593  0.073675  0.200767  0.289187       0.3
# 1  0.227845  0.490818  0.844340  0.659898  0.426648
# 2  0.269347  0.185778  0.713289  0.747584  0.304284
# 3  0.408769  0.455395  0.687348  0.890258  0.062237
# 4  0.976182  0.944025  0.906334  0.700883  0.732197

# %%
type(newdf['A'])
# Out:
# pandas.core.series.Series

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0       0.3  0.289187  0.200767  0.073675  0.302593
# 1  0.426648  0.659898  0.844340  0.490818  0.227845
# 2  0.304284  0.747584  0.713289  0.185778  0.269347
# 3  0.062237  0.890258  0.687348  0.455395  0.408769
# 4  0.732197  0.700883  0.906334  0.944025  0.976182

# %%
newdf2 = newdf.copy()

# %%
newdf2[0][0] = 345358
# Out:
# <ipython-input-50-7a39e6ae49e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0] = 345358

# %%
newdf
# Out:
#             0         1         2         3         4
# 0       34535  0.289187  0.200767  0.073675  0.302593
# 1    0.426648  0.659898  0.844340  0.490818  0.227845
# 2    0.304284  0.747584  0.713289  0.185778  0.269347
# 3    0.062237  0.890258  0.687348  0.455395  0.408769
# 4    0.732197  0.700883  0.906334  0.944025  0.976182
# ..        ...       ...       ...       ...       ...
# 329  0.755177  0.524794  0.722829  0.550112  0.520468
# 330  0.536398  0.031201  0.376468  0.882969  0.759195
# 331  0.782598  0.809622  0.754374  0.226985  0.221873
# 332  0.781552  0.322818  0.755281  0.243819  0.114079
# 333  0.241429  0.159000  0.811854  0.695264  0.106201
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0] = 654

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       654  0.289187  0.200767  0.073675  0.302593
# 1  0.426648  0.659898  0.844340  0.490818  0.227845

# %%
newdf.columns = list('ABCDE')

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0       654  0.289187  0.200767  0.073675  0.302593
# 1  0.426648  0.659898  0.844340  0.490818  0.227845

# %%
newdf.loc[0,0] = 3445

# %%
newdf
# Out:
#             A         B         C         D         E       0
# 0         654  0.289187  0.200767  0.073675  0.302593  3445.0
# 1    0.426648  0.659898  0.844340  0.490818  0.227845     NaN
# 2    0.304284  0.747584  0.713289  0.185778  0.269347     NaN
# 3    0.062237  0.890258  0.687348  0.455395  0.408769     NaN
# 4    0.732197  0.700883  0.906334  0.944025  0.976182     NaN
# ..        ...       ...       ...       ...       ...     ...
# 329  0.755177  0.524794  0.722829  0.550112  0.520468     NaN
# 330  0.536398  0.031201  0.376468  0.882969  0.759195     NaN
# 331  0.782598  0.809622  0.754374  0.226985  0.221873     NaN
# 332  0.781552  0.322818  0.755281  0.243819  0.114079     NaN
# 333  0.241429  0.159000  0.811854  0.695264  0.106201     NaN
#
# [334 rows x 6 columns]

# %%
newdf = newdf.drop(0,axis=1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0
# 333  0.159000  0.811854  0.106201
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,5],axis=0,inplace=True)

# %%
newdf.head(3)
# Out:
#           B         C         E
# 0  0.289187  0.200767  0.302593
# 2  0.747584  0.713289  0.269347
# 3  0.890258  0.687348  0.408769

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             B         C         E
# 0    0.289187  0.200767  0.302593
# 1    0.747584  0.713289  0.269347
# 2    0.890258  0.687348  0.408769
# 3    0.700883  0.906334  0.976182
# 4    0.439029  0.105033  0.177465
# ..        ...       ...       ...
# 327  0.524794  0.722829  0.520468
# 328  0.031201  0.376468  0.759195
# 329  0.809622  0.754374  0.221873
# 330  0.322818  0.755281  0.114079
# 331  0.159000  0.811854  0.106201
#
# [332 rows x 3 columns]

# %%
newdf.loc[:,['B']] = 56

# %%
newdf
# Out:
#       B         C         E
# 0    56  0.200767  0.302593
# 1    56  0.713289  0.269347
# 2    56  0.687348  0.408769
# 3    56  0.906334  0.976182
# 4    56  0.105033  0.177465
# ..   ..       ...       ...
# 327  56  0.722829  0.520468
# 328  56  0.376468  0.759195
# 329  56  0.754374  0.221873
# 330  56  0.755281  0.114079
# 331  56  0.811854  0.106201
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
newdf
# Out:
#       B         C         E
# 0    56  0.200767  0.302593
# 1    56  0.713289  0.269347
# 2    56  0.687348  0.408769
# 3    56  0.906334  0.976182
# 4    56  0.105033  0.177465
# ..   ..       ...       ...
# 327  56  0.722829  0.520468
# 328  56  0.376468  0.759195
# 329  56  0.754374  0.221873
# 330  56  0.755281  0.114079
# 331  56  0.811854  0.106201
#
# [332 rows x 3 columns]

# %%
newdf['C'] = 67

# %%
newdf
# Out:
#       B   C         E   c
# 0    56  67  0.302593  67
# 1    56  67  0.269347  67
# 2    56  67  0.408769  67
# 3    56  67  0.976182  67
# 4    56  67  0.177465  67
# ..   ..  ..       ...  ..
# 327  56  67  0.520468  67
# 328  56  67  0.759195  67
# 329  56  67  0.221873  67
# 330  56  67  0.114079  67
# 331  56  67  0.106201  67
#
# [332 rows x 4 columns]

# %%
newdf.drop('c',axis=1,inplace=True)

# %%
newdf
# Out:
#       B   C         E
# 0    56  67  0.302593
# 1    56  67  0.269347
# 2    56  67  0.408769
# 3    56  67  0.976182
# 4    56  67  0.177465
# ..   ..  ..       ...
# 327  56  67  0.520468
# 328  56  67  0.759195
# 329  56  67  0.221873
# 330  56  67  0.114079
# 331  56  67  0.106201
#
# [332 rows x 3 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df.head()
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df.drop_duplicates(subset=['name'], keep=False)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes
